# %%
from datetime import datetime
import datetime as dt
import pytz
import seaborn as sns
import matplotlib.pyplot as plt
import MetaTrader5 as mt5
import pandas as pd
import pytz
import numpy as np

# Display MetaTrader5 package information

print(f"MetaTrader5 package version: {mt5.__version__}")
print(f"MetaTrader5 author: {mt5.__author__}")


lst_ = ['EURUSD','USDJPY','EURJPY','EURCHF','EURAUD','EURGBP','EURSGD','EURNZD','USDCHF','USDCAD','GBPUSD',
        'GBPJPY','AUDUSD','AUDCHF','CADCHF','AUDSGD','CADSGD','NZDJPY','CHFJPY','NZDSGD','NZDCHF','CADJPY','GBPAUD',]
dict_ = {}

for i in lst_:
    # Initialize connection to the MetaTrader 5 terminal
    if not mt5.initialize():
        print("initialize() failed, error code =", mt5.last_error())
        quit()

    # Set the time zone to UTC
    timezone = pytz.timezone("Etc/UTC")    
    

    # Define the date and time range for historical data (weekly version)
    days_offset = dt.timedelta(weeks=1)  # Changed to represent one week
    local_time = dt.datetime.today()

    # Calculate the start and end dates for the weekly range
    utc_from = local_time - days_offset
    utc_to = local_time


     # Get historical price data for USD/JPY on a 30-minute timeframe
    symbol = i
    timeframe = mt5.TIMEFRAME_D1
    rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

        # Shut down the connection to the MetaTrader 5 terminal
    mt5.shutdown()

        # Display the first 10 elements of the obtained data
        # print("Display obtained data 'as is'")
        # for rate in rates[:10]:
        #     print(rate)
        #print(type(rates))

        # Create a DataFrame from the obtained data
    dict_[f'df_30_{i}'] = pd.DataFrame(rates)

        # Convert time in seconds to 'datetime' format
    dict_[f'df_30_{i}']['time'] = pd.to_datetime(dict_[f'df_30_{i}']['time'], unit='s')

        # Display the data as a DataFrame
    #     print("\nDisplay dataframe with data")
    #     print(dict_[f'df_30_{i}'].head(10))
# Out:
# MetaTrader5 package version: 5.0.45
# MetaTrader5 author: MetaQuotes Ltd.

# %%
fig, axs = plt.subplots(figsize=(15, 9))
range_ = dict_['df_30_EURUSD']['close']-dict_['df_30_EURUSD']['open']
plt.plot(dict_['df_30_EURUSD']['time'], range_, color='green')
plt.xlabel("Period")
plt.ylabel('Price Change')
plt.title('EURUSD')
# Out:
# Text(0.5, 1.0, 'EURUSD')

# %%
df_close = pd.concat([dict_[i]['close'] for i in dict_.keys() if 'JPY' not in i], axis='columns')

# %%
df_close.columns = [i for i in lst_ if 'JPY' not in i]

# %%
corr_close = df_close.corr()
corr_close.to_excel('Corr_weekly.xlsx')

# %%
threshold = 0.75

# Extracting pairs with correlation above the threshold
correlation_pairs = []

for i in range(len(corr_close.columns)):
    for j in range(i + 1, len(corr_close.columns)):
        if abs(corr_close.iloc[i, j]) >= threshold:
            correlation_pairs.append((corr_close.columns[i], corr_close.columns[j]))

print("Highly correlated pairs:")
#for pair in correlation_pairs:
    #print(pair)

with open('C:/Users/morara/corr_txt/High_corr.txt', 'w') as f:
    for pair in correlation_pairs:
        f.write(str(pair)+'\n')

# %%
fig, ax = plt.subplots(figsize=(17,15))
hm = sns.heatmap(corr_close, annot=True,cmap='coolwarm', linewidths=0.5, ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 fig, ax = plt.subplots(figsize=(17,15))
# ----> 2 hm = sns.heatmap(corr_close, annot=True,cmap='coolwarm', linewidths=0.5, ax=ax)
#       3 plt.show()
#
# NameError: name 'corr_close' is not defined
